# %%
from utils.drawtools import pltbar, pltpoly

# %%
accuracy = [[1.14216401,1.17892883,1.1510717,0.81211172,0.73967593,0.71549794], [1.14216401,1.17892883,1.1510717,0.81211172,0.73967593,0.71549794]]

# %%
pltpoly(len(accuracy[0]), accuracy, ['CATD', 'The Proposed Scheme'] , range(5, 11), 'RMSE', 1, 'Number of Workers', 'accu', show_num = False)
